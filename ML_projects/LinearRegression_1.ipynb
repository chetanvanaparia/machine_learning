# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = 11 * np.random.random((10, 1))
 
# y = a * x + b
y = 1.0 * x + 3.0

# %%
x
# Out:
# array([[ 5.75216086],
#        [ 8.92821783],
#        [ 5.88025981],
#        [ 5.96188761],
#        [ 8.5767103 ],
#        [ 5.0338114 ],
#        [ 2.67653231],
#        [ 4.57250495],
#        [10.01548074],
#        [ 9.68092118]])

# %%
 
# create a linear regression model
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
 
# predict y from the data where the x is predicted from the x
x_pred = np.linspace(0, 11, 100)
y_pred = model.predict(x_pred[:, np.newaxis])

# %%
np.linspace(0, 11, 100)

# %%
x_pred

# %%
np.newaxis , x_pred[:, np.newaxis].shape
# Out:
# (None, (100, 1))

# %%
plt.figure(figsize =(3, 5))
ax = plt.axes()
#ax=fig.add_axes([0,0,1,1])
ax.scatter(x, y)
plt.show()

# %%
# plot the results
plt.figure(figsize =(3, 5))
ax = plt.axes()
#ax=fig.add_axes([0,0,1,1])
ax.scatter(x, y)

ax.plot(x_pred, y_pred)
ax.set_xlabel('predictors')
ax.set_ylabel('criterion')
ax.axis('tight')
 
plt.show()

# %%
plt.scatter(x_pred , y_pred , marker='*')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter plot")
plt.show()
